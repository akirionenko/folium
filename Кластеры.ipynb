# %% [markdown]
# # Кластеры. Когда нужно больше точек

# %% [markdown]
# Используем набор данных `moscow_malls_info.csv` с информацией о торговых центрах Москвы
#
# Датасет хранит следующие данные:
#
# - `name` — название торгового центра;
# - `address` — адрес торгового центра;
# - `hours` — часы работы торгового центра;
# - `lat` — широта точки, в которой находится объект;
# - `lng` — долгота точки, в которой находится объект;
# - `rating` — рейтинг центра на Яндекс Картах;
# - `district` — район Москвы, в котором находится объект.
#
# Исследуем набор данных:

# %%
import pandas as pd

df = pd.read_csv('/datasets/moscow_malls_info.csv')
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('/datasets/moscow_malls_info.csv')
#       4 df.info()
#
# File c:\Users\kirio\anaconda3\envs\da_practicum_env2\lib\site-packages\pandas\io\parsers.py:610, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     605 kwds_defaults = _refine_defaults_read(
#     606     dialect, delimiter, delim_whitespace, engine, sep, defaults={"delimiter": ","}
#     607 )
#     608 kwds.update(kwds_defaults)
# --> 610 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\kirio\anaconda3\envs\da_practicum_env2\lib\site-packages\pandas\io\parsers.py:462, in _read(filepath_or_buffer, kwds)
#     459 _validate_names(kwds.get("names", None))
#     461 # Create the parser.
# --> 462 parser = TextFileReader(filepath_or_buffer, **kwds)
#     464 if chunksize or iterator:
#     465     return parser
#
# File c:\Users\kirio\anaconda3\envs\da_practicum_env2\lib\site-packages\pandas\io\parsers.py:819, in TextFileReader.__init__(self, f, engine, **kwds)
#     816 if "has_index_names" in kwds:
#     817     self.options["has_index_names"] = kwds["has_index_names"]
# --> 819 self._engine = self._make_engine(self.engine)
#
# File c:\Users\kirio\anaconda3\envs\da_practicum_env2\lib\site-packages\pandas\io\parsers.py:1050, in TextFileReader._make_engine(self, engine)
#    1046     raise ValueError(
#    1047         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1048     )
#    1049 # error: Too many arguments for "ParserBase"
# -> 1050 return mapping[engine](self.f, **self.options)
#
# File c:\Users\kirio\anaconda3\envs\da_practicum_env2\lib\site-packages\pandas\io\parsers.py:1867, in CParserWrapper.__init__(self, src, **kwds)
#    1864 kwds["usecols"] = self.usecols
#    1866 # open handles
# -> 1867 self._open_handles(src, kwds)
#    1868 assert self.handles is not None
#    1869 for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# File c:\Users\kirio\anaconda3\envs\da_practicum_env2\lib\site-packages\pandas\io\parsers.py:1362, in ParserBase._open_handles(self, src, kwds)
#    1358 def _open_handles(self, src: FilePathOrBuffer, kwds: Dict[str, Any]) -> None:
#    1359     """
#    1360     Let the readers open IOHanldes after they are done with their potential raises.
#    1361     """
# -> 1362     self.handles = get_handle(
#    1363         src,
#    1364         "r",
#    1365         encoding=kwds.get("encoding", None),
#    1366         compression=kwds.get("compression", None),
#    1367         memory_map=kwds.get("memory_map", False),
#    1368         storage_options=kwds.get("storage_options", None),
#    1369     )
#
# File c:\Users\kirio\anaconda3\envs\da_practicum_env2\lib\site-packages\pandas\io\common.py:642, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640         errors = "replace"
#     641     # Encoding
# --> 642     handle = open(
#     643         handle,
#     644         ioargs.mode,
#     645         encoding=ioargs.encoding,
#     646         errors=errors,
#     647         newline="",
#     648     )
#     649 else:
#     650     # Binary mode
#     651     handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/datasets/moscow_malls_info.csv'

# %% [markdown]
# Датасет хранит информацию о 786 торговых центрах.
#
# Посмотрим на первые строки:

# %%
df.head()
# Out:
#         name                                   address  \
# 0  Капитолий           Москва, Правобережная улица, 1Б
# 1     Dexter  Москва, МКАД, 78-й километр, 14, корп. 1
# 2        РИО  Москва, Дмитровское шоссе, 163А, корп. 1
# 3    Экстрим               Москва, Смольная улица, 63Б
# 4  Discovery                Москва, улица Дыбенко, 7/1
#
#                     hours        lat        lng  rating  \
# 0  ежедневно, 10:00–22:00  55.880803  37.449824     4.7
# 1  ежедневно, 10:00–21:00  55.893082  37.501263     4.3
# 2  ежедневно, 10:00–22:00  55.909388  37.539546     4.8
# 3  ежедневно, 10:00–21:00  55.869937  37.469915     4.7
# 4  ежедневно, 09:00–21:00  55.878662  37.479251     4.3
#
#                                   district
# 0          Северный административный округ
# 1          Северный административный округ
# 2  Северо-Восточный административный округ
# 3          Северный административный округ
# 4          Северный административный округ

# %% [markdown]
# Отметим первые 5 заведений на карте:

# %%
# подключаем библиотеку
from folium import Marker, Map

# moscow_lat - широта, moscow_lng – долгота
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера к первым 5 записям датафрейма
df[:5].apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16e7f6efe8cf30fc546b22b9198ad5a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16e7f6efe8cf30fc546b22b9198ad5a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_16e7f6efe8cf30fc546b22b9198ad5a0 = L.map(
#                 &quot;map_16e7f6efe8cf30fc546b22b9198ad5a0&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30f1142baefaf3c8dd56f3e7f72a9203 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16e7f6efe8cf30fc546b22b9198ad5a0);
#
#
#             var marker_1cf53969b22e5c88a756d7eb6343b173 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_16e7f6efe8cf30fc546b22b9198ad5a0);
#
#
#         var popup_7246674ebb579434fb2ed485e9977f51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_638c5baab4ae2683656fe2e19650e957 = $(`&lt;div id=&quot;html_638c5baab4ae2683656fe2e19650e957&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#             popup_7246674ebb579434fb2ed485e9977f51.setContent(html_638c5baab4ae2683656fe2e19650e957);
#
#
#         marker_1cf53969b22e5c88a756d7eb6343b173.bindPopup(popup_7246674ebb579434fb2ed485e9977f51)
#         ;
#
#
#
#
#             var marker_6484e6fb4ea0402d3099eec6af9a35ca = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_16e7f6efe8cf30fc546b22b9198ad5a0);
#
#
#         var popup_4de83ee1158a881b301f15be15e9d6cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7f6667c0bbbd2626df0860056504f8a8 = $(`&lt;div id=&quot;html_7f6667c0bbbd2626df0860056504f8a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#             popup_4de83ee1158a881b301f15be15e9d6cb.setContent(html_7f6667c0bbbd2626df0860056504f8a8);
#
#
#         marker_6484e6fb4ea0402d3099eec6af9a35ca.bindPopup(popup_4de83ee1158a881b301f15be15e9d6cb)
#         ;
#
#
#
#
#             var marker_8e191da199c44774dd16ca1a4732915c = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_16e7f6efe8cf30fc546b22b9198ad5a0);
#
#
#         var popup_42779b6714df9547cf0e70ddf6f17a14 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c1f206aafd95a5e52d9a6b162f249908 = $(`&lt;div id=&quot;html_c1f206aafd95a5e52d9a6b162f249908&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#             popup_42779b6714df9547cf0e70ddf6f17a14.setContent(html_c1f206aafd95a5e52d9a6b162f249908);
#
#
#         marker_8e191da199c44774dd16ca1a4732915c.bindPopup(popup_42779b6714df9547cf0e70ddf6f17a14)
#         ;
#
#
#
#
#             var marker_9559b72cca126ee7d391ddb20463d78b = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_16e7f6efe8cf30fc546b22b9198ad5a0);
#
#
#         var popup_4e304adb93409b18c1141cfd200daef9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0a80b0d5bf5fee2a725a63ec78904df8 = $(`&lt;div id=&quot;html_0a80b0d5bf5fee2a725a63ec78904df8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#             popup_4e304adb93409b18c1141cfd200daef9.setContent(html_0a80b0d5bf5fee2a725a63ec78904df8);
#
#
#         marker_9559b72cca126ee7d391ddb20463d78b.bindPopup(popup_4e304adb93409b18c1141cfd200daef9)
#         ;
#
#
#
#
#             var marker_4522b97988a76f11eaa51a4f3d494de0 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_16e7f6efe8cf30fc546b22b9198ad5a0);
#
#
#         var popup_fef9d15051a05f24d116e48133dbc72d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_429eebe716ee988d28fd145bbe7307f2 = $(`&lt;div id=&quot;html_429eebe716ee988d28fd145bbe7307f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#             popup_fef9d15051a05f24d116e48133dbc72d.setContent(html_429eebe716ee988d28fd145bbe7307f2);
#
#
#         marker_4522b97988a76f11eaa51a4f3d494de0.bindPopup(popup_fef9d15051a05f24d116e48133dbc72d)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# А теперь отметим сразу все здания:

# %%
# подключаем библиотеку
from folium import Marker

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера ко всем строкам датафрейма
df.apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c46540faffe37795dfcaaf71e7e46a3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c46540faffe37795dfcaaf71e7e46a3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c46540faffe37795dfcaaf71e7e46a3d = L.map(
#                 &quot;map_c46540faffe37795dfcaaf71e7e46a3d&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf6b2d3c5e9e3c145d905685a307c75d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c46540faffe37795dfcaaf71e7e46a3d);
#
#
#             var marker_7ac0b10dd7418e29768dd835e979454c = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_c46540faffe37795dfcaaf71e7e46a3d);
#
#
#         var popup_43f65589099948990bbf370a00644444 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_15b8b302ff3db517ca056ca5b734e561 = $(`&lt;div id=&quot;html_15b8b302ff3db517ca056ca5b734e561&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#             popup_43f65589099948990bbf370a00644444.setContent(html_15b8b302ff3db517ca056ca5b734e561);
#
#
#         marker_7ac0b10dd7418e29768dd835e979454c.bindPopup(popup_43f65589099948990bbf370a00644444)
#         ;
#
#
#
#
#             var marker_c656c2b5e8a44df47f82ca5420e04e3d = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_c46540faffe37795dfcaaf71e7e46a3d);
#
#
#         var popup_dc3735da99b733f14bb1a83058166434 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_96fd3139954db459cc6d867d90fa4e84 = $(`&lt;div id=&quot;html_96fd3139954db459cc6d867d90fa4e84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#             popup_dc3735da99b733f14bb1a83058166434.setContent(html_96fd3139954db459cc6d867d90fa4e84);
#
#
#         marker_c656c2b5e8a44df47f82ca5420e04e3d.bindPopup(popup_dc3735da99b733f14bb1a83058166434)
#         ;
#
#
#
#
#             var marker_8e38daf55a5d7ab173408be808caf2ca = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_c46540faffe37795dfcaaf71e7e46a3d);
#
#
#         var popup_62403f3264bfbaaa6d17fb3c61578a99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ef117764bb23df8fe1ae516cc3c980f6 = $(`&lt;div id=&quot;html_ef117764bb23df8fe1ae516cc3c980f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#             popup_62403f3264bfbaaa6d17fb3c61578a99.setContent(html_ef117764bb23df8fe1ae516cc3c980f6);
#
#
#         marker_8e38daf55a5d7ab173408be808caf2ca.bindPopup(popup_62403f3264bfbaaa6d17fb3c61578a99)
#         ;
#
#
#
#
#             var marker_0fd708bf45b2e31d02982b186f00f733 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_c46540faffe37795dfcaaf71e7e46a3d);
#
#
#         var popup_0a42e7c72ae367f801c7b2be33b83b55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_55b7a13b7cbff3660fa93fe1328b1db8 = $(`&lt;div id=&quot;html_55b7a13b7cbff3660fa93fe1328b1db8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#             popup_0a42e7c72ae367f801c7b2be33b83b55.setContent(html_55b7a13b7cbff3660fa93fe1328b1db8);
#
#
#         marker_0fd708bf45b2e31d02982b186f00f733.bindPopup(popup_0a42e7c72ae367f801c7b2be33b83b55)
#         ;
#
#
#
#
#             var marker_8e869fea58d56b1804b7a08a99301ac1 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_c46540faffe37795dfcaaf71e7e46a3d);
#
#
#         var popup_0d78fca0fb604c54fb260065210657b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_129bb150d995dfc595413f188037399f = $(`&lt;div id=&quot;html_129bb150d995dfc595413f188037399f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#             popup_0d78fca0fb604c54fb260065210657b1.setContent(html_129bb150d995dfc595413f188037399f);
#
#
#         marker_8e869fea58d56b1804b7a08a99301ac1.bindPopup(popup_0d78fca0fb604c54fb260065210657b1)
#         ;
#
#
#
#
#             var marker_47a1aa5d55e060e84cc92eede78f1a47 = L.marker(
#                 [55.893181, 37.50108],
#                 {}
#             ).addTo(map_c46540faffe37795dfcaaf71e7e46a3d);
#
#
#         var popup_a8d4b8860d37433079bf18c7db9797d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c17cf259626d51b9d99d9051fe67bf95 = $(`&lt;div id=&quot;html_c17cf259626d51b9d99d9051fe67bf95&quot; style=&quo

# %% [markdown]
# Здесь могут возникнуть проблемы:
#
# - Карта может долго отрисовываться, или рендериться (от англ. render, «выводить, отображать»), на слабых по производительности компьютерах или серверах;
# - Если на карте много точек, при уменьшении масштаба в ней будет сложно ориентироваться.
# - Из-за высокой нагрузки карта может зависать при передвижении по ней.
#
# Если отобразить на карте несколько тысяч точек, эти проблемы станут особенно заметны. Помогут кластеры — с их помощью можно поместить на карту много маркеров одновременно.
#
# Отметим все торговые центры на карте с помощью кластеров:

# %%
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
df.apply(create_clusters, axis=1)

# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_625b2171ae4a2734459fded7da165d64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_625b2171ae4a2734459fded7da165d64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_625b2171ae4a2734459fded7da165d64 = L.map(
#                 &quot;map_625b2171ae4a2734459fded7da165d64&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc3fdc44731cbee828ca1e6b5bbc5387 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_625b2171ae4a2734459fded7da165d64);
#
#
#             var marker_cluster_0124336778a4b15a780dfdc4424c301c = L.markerClusterGroup(
#                 {}
#             );
#             map_625b2171ae4a2734459fded7da165d64.addLayer(marker_cluster_0124336778a4b15a780dfdc4424c301c);
#
#
#             var marker_8ede4af5752c95724dbdc451d7565c4b = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_0124336778a4b15a780dfdc4424c301c);
#
#
#         var popup_ca3ffbecf0000cb67866eaef06d76aec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_08b1d50353dc2c2db39ebabff5acd4fd = $(`&lt;div id=&quot;html_08b1d50353dc2c2db39ebabff5acd4fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#             popup_ca3ffbecf0000cb67866eaef06d76aec.setContent(html_08b1d50353dc2c2db39ebabff5acd4fd);
#
#
#         marker_8ede4af5752c95724dbdc451d7565c4b.bindPopup(popup_ca3ffbecf0000cb67866eaef06d76aec)
#         ;
#
#
#
#
#             var marker_7070c5d1574d2faab8588f85468c3a19 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_0124336778a4b15a780dfdc4424c301c);
#
#
#         var popup_60060a0f4ec9baf5ead7f5469410eebf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5220fb96a17ed67caeebcc89ca5e1617 = $(`&lt;div id=&quot;html_5220fb96a17ed67caeebcc89ca5e1617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#             popup_60060a0f4ec9baf5ead7f5469410eebf.setContent(html_5220fb96a17ed67caeebcc89ca5e1617);
#
#
#         marker_7070c5d1574d2faab8588f85468c3a19.bindPopup(popup_60060a0f4ec9baf5ead7f5469410eebf)
#         ;
#
#
#
#
#             var marker_be051436ff4f5f4f88429d4d6f2de39a = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_0124336778a4b15a780dfdc4424c301c);
#
#
#         var popup_cb963fe8e45f9aa3b825445f946019e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3273d27b739e42f76349a89d155cd4b0 = $(`&lt;div id=&quot;html_3273d27b739e42f76349a89d155cd4b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#             popup_cb963fe8e45f9aa3b825445f946019e6.setContent(html_3273d27b739e42f76349a89d155cd4b0);
#
#
#         marker_be051436ff4f5f4f88429d4d6f2de39a.bindPopup(popup_cb963fe8e45f9aa3b825445f946019e6)
#         ;
#
#
#
#
#             var marker_af98ab586490378d6e98af4166e79001 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(marker_cluster_0124336778a4b15a780dfdc4424c301c);
#
#
#         var popup_3e4b94f2257ab6fadb66213559b6d752 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_2a2b51353eeb29481615f777f71a7f76 = $(`&lt;div id=&quot;html_2a2b51353eeb29481615f777f71a7f76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#             popup_3e4b94f2257ab6fadb66213559b6d752.setContent(html_2a2b51353eeb29481615f777f71a7f76);
#
#
#         marker_af98ab586490378d6e98af4166e79001.bindPopup(popup_3e4b94f2257ab6fadb66213559b6d752)
#         ;
#
#
#
#
#             var marker_cc73d82d5013d45e3745e8497cda4461 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(marker_cluster_0124336778a4b15a780dfdc4424c301c);
#
#
#         var popup_67c69d677be5535216d27a701b59e64b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ae2a8801902a65ab6aeca218e837b4e8 = $(`&lt;div id=&quot;html_ae2a8801902a65ab6aeca218e837b4e8&quot; style=&quot;width: 100.0

# %% [markdown]
# Попробуйте увеличить масштаб с помощью колёсика мышки или кнопок на карте. Вы увидите, что кластеры автоматически перегруппировываются: при достаточном приближении из кластеров начнут «выпадать» отдельные маркеры с торговыми центрами. Всплывающие окна и подсказки для них реализованы точно так же, как и для отдельных маркеров.

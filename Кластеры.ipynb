# %% [markdown]
# # Кластеры. Когда нужно больше точек

# %% [markdown]
# Используем набор данных `moscow_malls_info.csv` с информацией о торговых центрах Москвы
#
# Датасет хранит следующие данные:
#
# - `name` — название торгового центра;
# - `address` — адрес торгового центра;
# - `hours` — часы работы торгового центра;
# - `lat` — широта точки, в которой находится объект;
# - `lng` — долгота точки, в которой находится объект;
# - `rating` — рейтинг центра на Яндекс Картах;
# - `district` — район Москвы, в котором находится объект.
#
# Исследуем набор данных:

# %%
import pandas as pd

try:
   df = pd.read_csv('/datasets/moscow_malls_info.csv')
except:
   df = pd.read_csv('https://code.s3.yandex.net/datasets/moscow_malls_info.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      786 non-null    object
#  1   address   786 non-null    object
#  2   hours     685 non-null    object
#  3   lat       786 non-null    float64
#  4   lng       786 non-null    float64
#  5   rating    786 non-null    float64
#  6   district  764 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 43.1+ KB

# %% [markdown]
# Датасет хранит информацию о 786 торговых центрах.
#
# Посмотрим на первые строки:

# %%
df.head()
# Out:
#         name                                   address  \
# 0  Капитолий           Москва, Правобережная улица, 1Б
# 1     Dexter  Москва, МКАД, 78-й километр, 14, корп. 1
# 2        РИО  Москва, Дмитровское шоссе, 163А, корп. 1
# 3    Экстрим               Москва, Смольная улица, 63Б
# 4  Discovery                Москва, улица Дыбенко, 7/1
#
#                     hours        lat        lng  rating  \
# 0  ежедневно, 10:00–22:00  55.880803  37.449824     4.7
# 1  ежедневно, 10:00–21:00  55.893082  37.501263     4.3
# 2  ежедневно, 10:00–22:00  55.909388  37.539546     4.8
# 3  ежедневно, 10:00–21:00  55.869937  37.469915     4.7
# 4  ежедневно, 09:00–21:00  55.878662  37.479251     4.3
#
#                                   district
# 0          Северный административный округ
# 1          Северный административный округ
# 2  Северо-Восточный административный округ
# 3          Северный административный округ
# 4          Северный административный округ

# %% [markdown]
# Отметим первые 5 заведений на карте:

# %%
# подключаем библиотеку
from folium import Marker, Map

# moscow_lat - широта, moscow_lng – долгота
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера к первым 5 записям датафрейма
df[:5].apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d5170e1b4d4f3b7078702dce835fe87 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d5170e1b4d4f3b7078702dce835fe87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d5170e1b4d4f3b7078702dce835fe87 = L.map(
#                 &quot;map_8d5170e1b4d4f3b7078702dce835fe87&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8346a210e51dbcd1d098528963defa2d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8d5170e1b4d4f3b7078702dce835fe87);
#
#
#             var marker_f72b69cf5620cf99e8dae7a75f81ceaf = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_8d5170e1b4d4f3b7078702dce835fe87);
#
#
#         var popup_6dc472e80b62a70a289941abe6dd4ab6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_312447a1ea97e55e6ea01ae49f1ef38d = $(`&lt;div id=&quot;html_312447a1ea97e55e6ea01ae49f1ef38d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_6dc472e80b62a70a289941abe6dd4ab6.setContent(html_312447a1ea97e55e6ea01ae49f1ef38d);
#
#
#
#         marker_f72b69cf5620cf99e8dae7a75f81ceaf.bindPopup(popup_6dc472e80b62a70a289941abe6dd4ab6)
#         ;
#
#
#
#
#             var marker_e6fbb671205d30147f673e4acbda4d15 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_8d5170e1b4d4f3b7078702dce835fe87);
#
#
#         var popup_dd6096c10b46620443d3a1f7931c7d23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f8fe3b1cfd901543c9f8188a60a7b2c = $(`&lt;div id=&quot;html_0f8fe3b1cfd901543c9f8188a60a7b2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_dd6096c10b46620443d3a1f7931c7d23.setContent(html_0f8fe3b1cfd901543c9f8188a60a7b2c);
#
#
#
#         marker_e6fbb671205d30147f673e4acbda4d15.bindPopup(popup_dd6096c10b46620443d3a1f7931c7d23)
#         ;
#
#
#
#
#             var marker_6a3d182a3276aba4aac266be66b24698 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_8d5170e1b4d4f3b7078702dce835fe87);
#
#
#         var popup_10760be9050c4235b941758078a40516 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5de9478bf8db6ada16cdb9fc5fbafdff = $(`&lt;div id=&quot;html_5de9478bf8db6ada16cdb9fc5fbafdff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_10760be9050c4235b941758078a40516.setContent(html_5de9478bf8db6ada16cdb9fc5fbafdff);
#
#
#
#         marker_6a3d182a3276aba4aac266be66b24698.bindPopup(popup_10760be9050c4235b941758078a40516)
#         ;
#
#
#
#
#             var marker_dcfa53f67c8d9c33712726f53695dd82 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_8d5170e1b4d4f3b7078702dce835fe87);
#
#
#         var popup_b72c79cc744a66b38fe2871a42b744f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d49faa557f59f2dbd5b4df25af87fea6 = $(`&lt;div id=&quot;html_d49faa557f59f2dbd5b4df25af87fea6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_b72c79cc744a66b38fe2871a42b744f3.setContent(html_d49faa557f59f2dbd5b4df25af87fea6);
#
#
#
#         marker_dcfa53f67c8d9c33712726f53695dd82.bindPopup(popup_b72c79cc744a66b38fe2871a42b744f3)
#         ;
#
#
#
#
#             var marker_1b11ccd17ee61fba7f24dca62e87e533 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_8d5170e1b4d4f3b7078702dce835fe87);
#
#
#         var popup_edea63c486d368647e6ab862d2b4dfa7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c79842bdfd826f87e25c0c21af2d1c97 = $(`&lt;div id=&quot;html_c79842bdfd826f87e25c0c21af2d1c97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_edea63c486d368647e6ab862d2b4dfa7.setContent(html_c79842bdfd826f87e25c0c21af2d1c97);
#
#
#
#         marker_1b11ccd17ee61fba7f24dca62e87e533.bindPopup(popup_edea63c486d368647e6ab862d2b4dfa7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkita

# %% [markdown]
# А теперь отметим сразу все здания:

# %%
# подключаем библиотеку
from folium import Marker

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера ко всем строкам датафрейма
df.apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b307b0f89b5cfe8da4df7ef0dcbfbe8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b307b0f89b5cfe8da4df7ef0dcbfbe8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b307b0f89b5cfe8da4df7ef0dcbfbe8 = L.map(
#                 &quot;map_6b307b0f89b5cfe8da4df7ef0dcbfbe8&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6654a986bb74bc8c52748bdeb341e114 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b307b0f89b5cfe8da4df7ef0dcbfbe8);
#
#
#             var marker_c671a6b4db802b287fa37fdda9b5cdef = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_6b307b0f89b5cfe8da4df7ef0dcbfbe8);
#
#
#         var popup_1791b562529bd3487292479cef92328e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8308e3b4405bf57d6e7d5996a859aad3 = $(`&lt;div id=&quot;html_8308e3b4405bf57d6e7d5996a859aad3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_1791b562529bd3487292479cef92328e.setContent(html_8308e3b4405bf57d6e7d5996a859aad3);
#
#
#
#         marker_c671a6b4db802b287fa37fdda9b5cdef.bindPopup(popup_1791b562529bd3487292479cef92328e)
#         ;
#
#
#
#
#             var marker_b8b92f2ccea5fdeb18162696cc65c048 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_6b307b0f89b5cfe8da4df7ef0dcbfbe8);
#
#
#         var popup_a540655c19592e888aa50f4a3947b69a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80cc32ddc07b0383d2e4747cc0bc7c27 = $(`&lt;div id=&quot;html_80cc32ddc07b0383d2e4747cc0bc7c27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_a540655c19592e888aa50f4a3947b69a.setContent(html_80cc32ddc07b0383d2e4747cc0bc7c27);
#
#
#
#         marker_b8b92f2ccea5fdeb18162696cc65c048.bindPopup(popup_a540655c19592e888aa50f4a3947b69a)
#         ;
#
#
#
#
#             var marker_696a40764f6fc5e719c01a556d4b7333 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_6b307b0f89b5cfe8da4df7ef0dcbfbe8);
#
#
#         var popup_d9b761befb0502f372057a4e5dc43859 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fdbc507c1994a531808ebafada94e64e = $(`&lt;div id=&quot;html_fdbc507c1994a531808ebafada94e64e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_d9b761befb0502f372057a4e5dc43859.setContent(html_fdbc507c1994a531808ebafada94e64e);
#
#
#
#         marker_696a40764f6fc5e719c01a556d4b7333.bindPopup(popup_d9b761befb0502f372057a4e5dc43859)
#         ;
#
#
#
#
#             var marker_d8afb4b38ab41130bd5e1235d133ecf0 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_6b307b0f89b5cfe8da4df7ef0dcbfbe8);
#
#
#         var popup_ce1e9e7ba2a431d04ab19ea118da8a83 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ffc916c4e6f5f69ac692ed13d0b83537 = $(`&lt;div id=&quot;html_ffc916c4e6f5f69ac692ed13d0b83537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_ce1e9e7ba2a431d04ab19ea118da8a83.setContent(html_ffc916c4e6f5f69ac692ed13d0b83537);
#
#
#
#         marker_d8afb4b38ab41130bd5e1235d133ecf0.bindPopup(popup_ce1e9e7ba2a431d04ab19ea118da8a83)
#         ;
#
#
#
#
#             var marker_f0815906efef7a908b9d08ec1f096062 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_6b307b0f89b5cfe8da4df7ef0dcbfbe8);
#
#
#         var popup_8b290b8d03521e9a0dd60a68d76b39ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a23a78b5cfad5424e2a241289d541ca1 = $(`&lt;div id=&quot;html_a23a78b5cfad5424e2a241289d541ca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_8b290b8d03521e9a0dd60a68d76b39ec.setContent(html_a23a78b5cfad5424e2a241289d541ca1);
#
#
#
#         marker_f0815906efef7a908b9d08ec1f096062.bindPopup(popup_8b290b8d03521e9a0dd60a68d76b39ec)
#         ;
#
#
#
#
#             var marker_2290f1c7430c9b3f25e7920b00807055 = L.marker(
#                 [55.893181, 37.50108],
#                 {}

# %% [markdown]
# Здесь могут возникнуть проблемы:
#
# - Карта может долго отрисовываться, или рендериться (от англ. render, «выводить, отображать»), на слабых по производительности компьютерах или серверах;
# - Если на карте много точек, при уменьшении масштаба в ней будет сложно ориентироваться.
# - Из-за высокой нагрузки карта может зависать при передвижении по ней.
#
# Если отобразить на карте несколько тысяч точек, эти проблемы станут особенно заметны. Помогут кластеры — с их помощью можно поместить на карту много маркеров одновременно.
#
# Отметим все торговые центры на карте с помощью кластеров:

# %%
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
df.apply(create_clusters, axis=1)

# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f30820f683ca7f2cc0682d8223cc87d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f30820f683ca7f2cc0682d8223cc87d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f30820f683ca7f2cc0682d8223cc87d1 = L.map(
#                 &quot;map_f30820f683ca7f2cc0682d8223cc87d1&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fc4629894cf5cad47ae6ab9271ceb85 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f30820f683ca7f2cc0682d8223cc87d1);
#
#
#             var marker_cluster_8e858ad5eba3169ee4d03df5c2fae463 = L.markerClusterGroup(
#                 {}
#             );
#             map_f30820f683ca7f2cc0682d8223cc87d1.addLayer(marker_cluster_8e858ad5eba3169ee4d03df5c2fae463);
#
#
#             var marker_4341e76370bbff1388556980047d09b7 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_8e858ad5eba3169ee4d03df5c2fae463);
#
#
#         var popup_1a2d94eb4bd40dff0fcd7045bd17f378 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39419192edef9ee43bfeaffaa082fe13 = $(`&lt;div id=&quot;html_39419192edef9ee43bfeaffaa082fe13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_1a2d94eb4bd40dff0fcd7045bd17f378.setContent(html_39419192edef9ee43bfeaffaa082fe13);
#
#
#
#         marker_4341e76370bbff1388556980047d09b7.bindPopup(popup_1a2d94eb4bd40dff0fcd7045bd17f378)
#         ;
#
#
#
#
#             var marker_a72072bf94040f68f915aad18de610f4 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_8e858ad5eba3169ee4d03df5c2fae463);
#
#
#         var popup_0a1644f5d7b9fea9466cc9562201872b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ee75f977a70a10203d2b4f82c6b74bf = $(`&lt;div id=&quot;html_9ee75f977a70a10203d2b4f82c6b74bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_0a1644f5d7b9fea9466cc9562201872b.setContent(html_9ee75f977a70a10203d2b4f82c6b74bf);
#
#
#
#         marker_a72072bf94040f68f915aad18de610f4.bindPopup(popup_0a1644f5d7b9fea9466cc9562201872b)
#         ;
#
#
#
#
#             var marker_83b6f825f6d245cb265a49b832b18fba = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_8e858ad5eba3169ee4d03df5c2fae463);
#
#
#         var popup_fce408482ab2cb6007ac74949fce3251 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f793dce9b23aeaecf4d3f5b8962f9f5 = $(`&lt;div id=&quot;html_9f793dce9b23aeaecf4d3f5b8962f9f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_fce408482ab2cb6007ac74949fce3251.setContent(html_9f793dce9b23aeaecf4d3f5b8962f9f5);
#
#
#
#         marker_83b6f825f6d245cb265a49b832b18fba.bindPopup(popup_fce408482ab2cb6007ac74949fce3251)
#         ;
#
#
#
#
#             var marker_19a41c817d0494d0e116218f3983eb6e = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(marker_cluster_8e858ad5eba3169ee4d03df5c2fae463);
#
#
#         var popup_ad20d6483e9eb04a85c9cd953339fd31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8a8df8d69f2ecc7e3a7ebdc5830a83a = $(`&lt;div id=&quot;html_a8a8df8d69f2ecc7e3a7ebdc5830a83a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_ad20d6483e9eb04a85c9cd953339fd31.setContent(html_a8a8df8d69f2ecc7e3a7ebdc5830a83a);
#
#
#
#         marker_19a41c817d0494d0e116218f3983eb6e.bindPopup(popup_ad20d6483e9eb04a85c9cd953339fd31)
#         ;
#
#
#
#
#             var marker_21ac87c2877d69ad1e023c21caabd360 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(marker_cluster_8e858ad5eba3169ee4d03df5c2fae463)

# %% [markdown]
# Попробуйте увеличить масштаб с помощью колёсика мышки или кнопок на карте. Вы увидите, что кластеры автоматически перегруппировываются: при достаточном приближении из кластеров начнут «выпадать» отдельные маркеры с торговыми центрами. Всплывающие окна и подсказки для них реализованы точно так же, как и для отдельных маркеров.

# %% [markdown]
# # Кластеры. Когда нужно больше точек

# %% [markdown]
# Используем набор данных `moscow_malls_info.csv` с информацией о торговых центрах Москвы
#
# Датасет хранит следующие данные:
#
# - `name` — название торгового центра;
# - `address` — адрес торгового центра;
# - `hours` — часы работы торгового центра;
# - `lat` — широта точки, в которой находится объект;
# - `lng` — долгота точки, в которой находится объект;
# - `rating` — рейтинг центра на Яндекс Картах;
# - `district` — район Москвы, в котором находится объект.
#
# Исследуем набор данных:

# %%
import pandas as pd

try:
   df = pd.read_csv('/datasets/moscow_malls_info.csv')
except:
   df = pd.read_csv('https://code.s3.yandex.net/datasets/moscow_malls_info.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      786 non-null    object
#  1   address   786 non-null    object
#  2   hours     685 non-null    object
#  3   lat       786 non-null    float64
#  4   lng       786 non-null    float64
#  5   rating    786 non-null    float64
#  6   district  764 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 43.1+ KB

# %% [markdown]
# Датасет хранит информацию о 786 торговых центрах.
#
# Посмотрим на первые строки:

# %%
df.head()
# Out:
#         name                                   address  \
# 0  Капитолий           Москва, Правобережная улица, 1Б
# 1     Dexter  Москва, МКАД, 78-й километр, 14, корп. 1
# 2        РИО  Москва, Дмитровское шоссе, 163А, корп. 1
# 3    Экстрим               Москва, Смольная улица, 63Б
# 4  Discovery                Москва, улица Дыбенко, 7/1
#
#                     hours        lat        lng  rating  \
# 0  ежедневно, 10:00–22:00  55.880803  37.449824     4.7
# 1  ежедневно, 10:00–21:00  55.893082  37.501263     4.3
# 2  ежедневно, 10:00–22:00  55.909388  37.539546     4.8
# 3  ежедневно, 10:00–21:00  55.869937  37.469915     4.7
# 4  ежедневно, 09:00–21:00  55.878662  37.479251     4.3
#
#                                   district
# 0          Северный административный округ
# 1          Северный административный округ
# 2  Северо-Восточный административный округ
# 3          Северный административный округ
# 4          Северный административный округ

# %% [markdown]
# Отметим первые 5 заведений на карте:

# %%
# подключаем библиотеку
from folium import Marker, Map

# moscow_lat - широта, moscow_lng – долгота
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера к первым 5 записям датафрейма
df[:5].apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_755f4697338868765653d6d53879e00d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_755f4697338868765653d6d53879e00d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_755f4697338868765653d6d53879e00d = L.map(
#                 &quot;map_755f4697338868765653d6d53879e00d&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2794d7175aabf7f190e3cc252062efb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_755f4697338868765653d6d53879e00d);
#
#
#             var marker_2f5baa86614a57b830e638a816544924 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_755f4697338868765653d6d53879e00d);
#
#
#         var popup_418076b24c34228e98a342021dff5bca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27a061cb41f3df4e2aa86ba9e1f5c8d9 = $(`&lt;div id=&quot;html_27a061cb41f3df4e2aa86ba9e1f5c8d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_418076b24c34228e98a342021dff5bca.setContent(html_27a061cb41f3df4e2aa86ba9e1f5c8d9);
#
#
#
#         marker_2f5baa86614a57b830e638a816544924.bindPopup(popup_418076b24c34228e98a342021dff5bca)
#         ;
#
#
#
#
#             var marker_e62baa8418ffdd86954b84b59bb770a8 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_755f4697338868765653d6d53879e00d);
#
#
#         var popup_34dcff7cb3f5ab116e7f48dd88d75665 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c39050685b61dd5230bce30a3f25dab = $(`&lt;div id=&quot;html_7c39050685b61dd5230bce30a3f25dab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_34dcff7cb3f5ab116e7f48dd88d75665.setContent(html_7c39050685b61dd5230bce30a3f25dab);
#
#
#
#         marker_e62baa8418ffdd86954b84b59bb770a8.bindPopup(popup_34dcff7cb3f5ab116e7f48dd88d75665)
#         ;
#
#
#
#
#             var marker_a418592696a9fc2cef4c1024abafff2e = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_755f4697338868765653d6d53879e00d);
#
#
#         var popup_05cb785556eb31428f7c32cd348970fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5360b8fca70addd5286928df98f4fc9e = $(`&lt;div id=&quot;html_5360b8fca70addd5286928df98f4fc9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_05cb785556eb31428f7c32cd348970fa.setContent(html_5360b8fca70addd5286928df98f4fc9e);
#
#
#
#         marker_a418592696a9fc2cef4c1024abafff2e.bindPopup(popup_05cb785556eb31428f7c32cd348970fa)
#         ;
#
#
#
#
#             var marker_a1efcfd9b0b3d3d23d46556417f8e72e = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_755f4697338868765653d6d53879e00d);
#
#
#         var popup_70a0742a4ee228b1a0d7f30ada625088 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c76bc37d0a0fcb5d638fe10c7726af3b = $(`&lt;div id=&quot;html_c76bc37d0a0fcb5d638fe10c7726af3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_70a0742a4ee228b1a0d7f30ada625088.setContent(html_c76bc37d0a0fcb5d638fe10c7726af3b);
#
#
#
#         marker_a1efcfd9b0b3d3d23d46556417f8e72e.bindPopup(popup_70a0742a4ee228b1a0d7f30ada625088)
#         ;
#
#
#
#
#             var marker_596533bb29025906f1f52c4f0f62ce6d = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_755f4697338868765653d6d53879e00d);
#
#
#         var popup_42891381ad22ab0988448ed3d0f18773 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5de905f24da0f80b8149014a2f7f853a = $(`&lt;div id=&quot;html_5de905f24da0f80b8149014a2f7f853a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_42891381ad22ab0988448ed3d0f18773.setContent(html_5de905f24da0f80b8149014a2f7f853a);
#
#
#
#         marker_596533bb29025906f1f52c4f0f62ce6d.bindPopup(popup_42891381ad22ab0988448ed3d0f18773)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkita

# %% [markdown]
# А теперь отметим сразу все здания:

# %%
# подключаем библиотеку
from folium import Marker

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера ко всем строкам датафрейма
df.apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bbc850e3da24f7f48f3b5ee1b6d7057 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bbc850e3da24f7f48f3b5ee1b6d7057&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bbc850e3da24f7f48f3b5ee1b6d7057 = L.map(
#                 &quot;map_4bbc850e3da24f7f48f3b5ee1b6d7057&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31d8a3d087b4611c63cd8c905996c494 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4bbc850e3da24f7f48f3b5ee1b6d7057);
#
#
#             var marker_7123d77b46ec79a691fd36e6c29cf732 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_4bbc850e3da24f7f48f3b5ee1b6d7057);
#
#
#         var popup_8ca9283d071ebf13d18b427b942bca50 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a296c19838e0d0576b9b9bbc838c7487 = $(`&lt;div id=&quot;html_a296c19838e0d0576b9b9bbc838c7487&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_8ca9283d071ebf13d18b427b942bca50.setContent(html_a296c19838e0d0576b9b9bbc838c7487);
#
#
#
#         marker_7123d77b46ec79a691fd36e6c29cf732.bindPopup(popup_8ca9283d071ebf13d18b427b942bca50)
#         ;
#
#
#
#
#             var marker_35cc61d63686421fdfe7b6bffe5ea875 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_4bbc850e3da24f7f48f3b5ee1b6d7057);
#
#
#         var popup_43ed7148a7a047fd1373891906a25004 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2853313d3806c1163f3a8ac6bce927d = $(`&lt;div id=&quot;html_d2853313d3806c1163f3a8ac6bce927d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_43ed7148a7a047fd1373891906a25004.setContent(html_d2853313d3806c1163f3a8ac6bce927d);
#
#
#
#         marker_35cc61d63686421fdfe7b6bffe5ea875.bindPopup(popup_43ed7148a7a047fd1373891906a25004)
#         ;
#
#
#
#
#             var marker_89ad1c7cd1c281677aee469fb0590a1d = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_4bbc850e3da24f7f48f3b5ee1b6d7057);
#
#
#         var popup_8a4c5328a55aa5a4f4832262140417f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48cf9c5eca3d5a62da2aa9c74da09934 = $(`&lt;div id=&quot;html_48cf9c5eca3d5a62da2aa9c74da09934&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_8a4c5328a55aa5a4f4832262140417f3.setContent(html_48cf9c5eca3d5a62da2aa9c74da09934);
#
#
#
#         marker_89ad1c7cd1c281677aee469fb0590a1d.bindPopup(popup_8a4c5328a55aa5a4f4832262140417f3)
#         ;
#
#
#
#
#             var marker_434b2e6a64c8eb4beca9a08ceb304a22 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_4bbc850e3da24f7f48f3b5ee1b6d7057);
#
#
#         var popup_5856ed8c5cd151366a76806f6952b290 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b028b707bbf03a7ba75d0af2533baf94 = $(`&lt;div id=&quot;html_b028b707bbf03a7ba75d0af2533baf94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_5856ed8c5cd151366a76806f6952b290.setContent(html_b028b707bbf03a7ba75d0af2533baf94);
#
#
#
#         marker_434b2e6a64c8eb4beca9a08ceb304a22.bindPopup(popup_5856ed8c5cd151366a76806f6952b290)
#         ;
#
#
#
#
#             var marker_1bbbe8fb5bc09f527b82fdf7f7363940 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_4bbc850e3da24f7f48f3b5ee1b6d7057);
#
#
#         var popup_91b2e2ba81815e0e9cbffc5c5ac2ebf5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe5f48aed4f17dcb06f95db94bbe3a92 = $(`&lt;div id=&quot;html_fe5f48aed4f17dcb06f95db94bbe3a92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_91b2e2ba81815e0e9cbffc5c5ac2ebf5.setContent(html_fe5f48aed4f17dcb06f95db94bbe3a92);
#
#
#
#         marker_1bbbe8fb5bc09f527b82fdf7f7363940.bindPopup(popup_91b2e2ba81815e0e9cbffc5c5ac2ebf5)
#         ;
#
#
#
#
#             var marker_8aaef18017fabf73f39e2956a0cf37ac = L.marker(
#                 [55.893181, 37.50108],
#                 {}

# %% [markdown]
# Здесь могут возникнуть проблемы:
#
# - Карта может долго отрисовываться, или рендериться (от англ. render, «выводить, отображать»), на слабых по производительности компьютерах или серверах;
# - Если на карте много точек, при уменьшении масштаба в ней будет сложно ориентироваться.
# - Из-за высокой нагрузки карта может зависать при передвижении по ней.
#
# Если отобразить на карте несколько тысяч точек, эти проблемы станут особенно заметны. Помогут кластеры — с их помощью можно поместить на карту много маркеров одновременно.
#
# Отметим все торговые центры на карте с помощью кластеров:

# %%
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
df.apply(create_clusters, axis=1)

# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47fdd8cd5cb421124b24b0745df459e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47fdd8cd5cb421124b24b0745df459e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47fdd8cd5cb421124b24b0745df459e2 = L.map(
#                 &quot;map_47fdd8cd5cb421124b24b0745df459e2&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a0fa7f730527f57164c43ba4ac62620 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47fdd8cd5cb421124b24b0745df459e2);
#
#
#             var marker_cluster_34eba55bef8a8ad8ae9058232b2e8a6a = L.markerClusterGroup(
#                 {}
#             );
#             map_47fdd8cd5cb421124b24b0745df459e2.addLayer(marker_cluster_34eba55bef8a8ad8ae9058232b2e8a6a);
#
#
#             var marker_550c3c7a55f1ac32b05a91653c3dff45 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_34eba55bef8a8ad8ae9058232b2e8a6a);
#
#
#         var popup_b5bb45c51922d9ef3fc3e10958132e8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a5a977fe7184001f7a8cb6512f6a278 = $(`&lt;div id=&quot;html_6a5a977fe7184001f7a8cb6512f6a278&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_b5bb45c51922d9ef3fc3e10958132e8b.setContent(html_6a5a977fe7184001f7a8cb6512f6a278);
#
#
#
#         marker_550c3c7a55f1ac32b05a91653c3dff45.bindPopup(popup_b5bb45c51922d9ef3fc3e10958132e8b)
#         ;
#
#
#
#
#             var marker_eca25c23af25493393706f118f41a482 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_34eba55bef8a8ad8ae9058232b2e8a6a);
#
#
#         var popup_29a2d9ed284290b73c3caba46cff3c37 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c2c3e6973d0d41f486fe2cb95a35252 = $(`&lt;div id=&quot;html_9c2c3e6973d0d41f486fe2cb95a35252&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_29a2d9ed284290b73c3caba46cff3c37.setContent(html_9c2c3e6973d0d41f486fe2cb95a35252);
#
#
#
#         marker_eca25c23af25493393706f118f41a482.bindPopup(popup_29a2d9ed284290b73c3caba46cff3c37)
#         ;
#
#
#
#
#             var marker_8e217a78388bdd114dcb5e9b8de48ac7 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_34eba55bef8a8ad8ae9058232b2e8a6a);
#
#
#         var popup_9a5bd882ea753d6619f0fb7a7c17be54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c66b6d87e159195bdee4ba9512177ee9 = $(`&lt;div id=&quot;html_c66b6d87e159195bdee4ba9512177ee9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_9a5bd882ea753d6619f0fb7a7c17be54.setContent(html_c66b6d87e159195bdee4ba9512177ee9);
#
#
#
#         marker_8e217a78388bdd114dcb5e9b8de48ac7.bindPopup(popup_9a5bd882ea753d6619f0fb7a7c17be54)
#         ;
#
#
#
#
#             var marker_8d70ca3c299552ba1f01f71b652b4108 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(marker_cluster_34eba55bef8a8ad8ae9058232b2e8a6a);
#
#
#         var popup_89b19a19523b2257fbc47f19fbd61d89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01b1ef929deba8c3b5865db971adfd8b = $(`&lt;div id=&quot;html_01b1ef929deba8c3b5865db971adfd8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_89b19a19523b2257fbc47f19fbd61d89.setContent(html_01b1ef929deba8c3b5865db971adfd8b);
#
#
#
#         marker_8d70ca3c299552ba1f01f71b652b4108.bindPopup(popup_89b19a19523b2257fbc47f19fbd61d89)
#         ;
#
#
#
#
#             var marker_1426087a741fdea85d11b748f5ea7fb8 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(marker_cluster_34eba55bef8a8ad8ae9058232b2e8a6a)

# %% [markdown]
# Попробуйте увеличить масштаб с помощью колёсика мышки или кнопок на карте. Вы увидите, что кластеры автоматически перегруппировываются: при достаточном приближении из кластеров начнут «выпадать» отдельные маркеры с торговыми центрами. Всплывающие окна и подсказки для них реализованы точно так же, как и для отдельных маркеров.

# %% [markdown]
# # Кластеры. Когда нужно больше точек

# %% [markdown]
# Используем набор данных `moscow_malls_info.csv` с информацией о торговых центрах Москвы
#
# Датасет хранит следующие данные:
#
# - `name` — название торгового центра;
# - `address` — адрес торгового центра;
# - `hours` — часы работы торгового центра;
# - `lat` — широта точки, в которой находится объект;
# - `lng` — долгота точки, в которой находится объект;
# - `rating` — рейтинг центра на Яндекс Картах;
# - `district` — район Москвы, в котором находится объект.
#
# Исследуем набор данных:

# %%
import pandas as pd

try:
   df = pd.read_csv('/datasets/moscow_malls_info.csv')
except:
   df = pd.read_csv('https://code.s3.yandex.net/datasets/moscow_malls_info.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786 entries, 0 to 785
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      786 non-null    object
#  1   address   786 non-null    object
#  2   hours     685 non-null    object
#  3   lat       786 non-null    float64
#  4   lng       786 non-null    float64
#  5   rating    786 non-null    float64
#  6   district  764 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 43.1+ KB

# %% [markdown]
# Датасет хранит информацию о 786 торговых центрах.
#
# Посмотрим на первые строки:

# %%
df.head()
# Out:
#         name                                   address  \
# 0  Капитолий           Москва, Правобережная улица, 1Б
# 1     Dexter  Москва, МКАД, 78-й километр, 14, корп. 1
# 2        РИО  Москва, Дмитровское шоссе, 163А, корп. 1
# 3    Экстрим               Москва, Смольная улица, 63Б
# 4  Discovery                Москва, улица Дыбенко, 7/1
#
#                     hours        lat        lng  rating  \
# 0  ежедневно, 10:00–22:00  55.880803  37.449824     4.7
# 1  ежедневно, 10:00–21:00  55.893082  37.501263     4.3
# 2  ежедневно, 10:00–22:00  55.909388  37.539546     4.8
# 3  ежедневно, 10:00–21:00  55.869937  37.469915     4.7
# 4  ежедневно, 09:00–21:00  55.878662  37.479251     4.3
#
#                                   district
# 0          Северный административный округ
# 1          Северный административный округ
# 2  Северо-Восточный административный округ
# 3          Северный административный округ
# 4          Северный административный округ

# %% [markdown]
# Отметим первые 5 заведений на карте:

# %%
# подключаем библиотеку
from folium import Marker, Map

# moscow_lat - широта, moscow_lng – долгота
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера к первым 5 записям датафрейма
df[:5].apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_473e80ac118a03c2a0b9107ed9a262ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_473e80ac118a03c2a0b9107ed9a262ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_473e80ac118a03c2a0b9107ed9a262ee = L.map(
#                 &quot;map_473e80ac118a03c2a0b9107ed9a262ee&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23916740897c067306a80dead8bc6f56 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_473e80ac118a03c2a0b9107ed9a262ee);
#
#
#             var marker_265a1592306e320268439ae2177b53b0 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_473e80ac118a03c2a0b9107ed9a262ee);
#
#
#         var popup_b86b31bac1a6357ced88ef0256ef93ce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_785654f8050c54e2117ed3a42964b021 = $(`&lt;div id=&quot;html_785654f8050c54e2117ed3a42964b021&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_b86b31bac1a6357ced88ef0256ef93ce.setContent(html_785654f8050c54e2117ed3a42964b021);
#
#
#
#         marker_265a1592306e320268439ae2177b53b0.bindPopup(popup_b86b31bac1a6357ced88ef0256ef93ce)
#         ;
#
#
#
#
#             var marker_18063fe011da1ed87697820948f1df37 = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_473e80ac118a03c2a0b9107ed9a262ee);
#
#
#         var popup_eae18c0c832d9bb3ef0533a37cb60cb6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf131fc6c3e5255a7c5b7ecf129c45c0 = $(`&lt;div id=&quot;html_bf131fc6c3e5255a7c5b7ecf129c45c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_eae18c0c832d9bb3ef0533a37cb60cb6.setContent(html_bf131fc6c3e5255a7c5b7ecf129c45c0);
#
#
#
#         marker_18063fe011da1ed87697820948f1df37.bindPopup(popup_eae18c0c832d9bb3ef0533a37cb60cb6)
#         ;
#
#
#
#
#             var marker_68ba4dd6ebce55dc7a06a29268de1918 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_473e80ac118a03c2a0b9107ed9a262ee);
#
#
#         var popup_55b7bc41ba72d891b3eb99aa1ea33fda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4335f1b69bbd679a9fa7fe77a878e27b = $(`&lt;div id=&quot;html_4335f1b69bbd679a9fa7fe77a878e27b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_55b7bc41ba72d891b3eb99aa1ea33fda.setContent(html_4335f1b69bbd679a9fa7fe77a878e27b);
#
#
#
#         marker_68ba4dd6ebce55dc7a06a29268de1918.bindPopup(popup_55b7bc41ba72d891b3eb99aa1ea33fda)
#         ;
#
#
#
#
#             var marker_9686b99ad38ef042f51a52ea6af4f4f9 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_473e80ac118a03c2a0b9107ed9a262ee);
#
#
#         var popup_cae9480228ef474ecca4d0d34774233f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe79afa0bcb454040d4f5ab8fc2f7380 = $(`&lt;div id=&quot;html_fe79afa0bcb454040d4f5ab8fc2f7380&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_cae9480228ef474ecca4d0d34774233f.setContent(html_fe79afa0bcb454040d4f5ab8fc2f7380);
#
#
#
#         marker_9686b99ad38ef042f51a52ea6af4f4f9.bindPopup(popup_cae9480228ef474ecca4d0d34774233f)
#         ;
#
#
#
#
#             var marker_7b1690f34df63c167b82068846e6ce54 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_473e80ac118a03c2a0b9107ed9a262ee);
#
#
#         var popup_635940b13971e3063e3a0825ed442575 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2cb2e5c8714e675f30b3026b7ca96b44 = $(`&lt;div id=&quot;html_2cb2e5c8714e675f30b3026b7ca96b44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_635940b13971e3063e3a0825ed442575.setContent(html_2cb2e5c8714e675f30b3026b7ca96b44);
#
#
#
#         marker_7b1690f34df63c167b82068846e6ce54.bindPopup(popup_635940b13971e3063e3a0825ed442575)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkita

# %% [markdown]
# А теперь отметим сразу все здания:

# %%
# подключаем библиотеку
from folium import Marker

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его на карту
def create_marker(row):
    Marker([row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}"
    ).add_to(m)

# применяем функцию для создания маркера ко всем строкам датафрейма
df.apply(create_marker, axis=1)
    
# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e8fa9c41c79e78e2c7bb3072bcfe950 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e8fa9c41c79e78e2c7bb3072bcfe950&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e8fa9c41c79e78e2c7bb3072bcfe950 = L.map(
#                 &quot;map_1e8fa9c41c79e78e2c7bb3072bcfe950&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aaf9ae98fa7324e62646d7fe0e6d23be = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1e8fa9c41c79e78e2c7bb3072bcfe950);
#
#
#             var marker_95973e61788b477c86976053dcd78767 = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(map_1e8fa9c41c79e78e2c7bb3072bcfe950);
#
#
#         var popup_d7a7ba61e1a9353ff3a34b3f5398e640 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_295c83bd7dacdedce52c7abb45ea0fdb = $(`&lt;div id=&quot;html_295c83bd7dacdedce52c7abb45ea0fdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_d7a7ba61e1a9353ff3a34b3f5398e640.setContent(html_295c83bd7dacdedce52c7abb45ea0fdb);
#
#
#
#         marker_95973e61788b477c86976053dcd78767.bindPopup(popup_d7a7ba61e1a9353ff3a34b3f5398e640)
#         ;
#
#
#
#
#             var marker_0289c40795ff8145b9418115f8805a6c = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(map_1e8fa9c41c79e78e2c7bb3072bcfe950);
#
#
#         var popup_120767af616385411befbb4a451a200c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28894a2736d5269dc3c9d24dfbe27244 = $(`&lt;div id=&quot;html_28894a2736d5269dc3c9d24dfbe27244&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_120767af616385411befbb4a451a200c.setContent(html_28894a2736d5269dc3c9d24dfbe27244);
#
#
#
#         marker_0289c40795ff8145b9418115f8805a6c.bindPopup(popup_120767af616385411befbb4a451a200c)
#         ;
#
#
#
#
#             var marker_2128875eca8d14f325d4f48c32895216 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(map_1e8fa9c41c79e78e2c7bb3072bcfe950);
#
#
#         var popup_9560ad4681a01ca187f00c82106ba9c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b7f5848c376c32e00344d9cb211ce1b = $(`&lt;div id=&quot;html_1b7f5848c376c32e00344d9cb211ce1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_9560ad4681a01ca187f00c82106ba9c0.setContent(html_1b7f5848c376c32e00344d9cb211ce1b);
#
#
#
#         marker_2128875eca8d14f325d4f48c32895216.bindPopup(popup_9560ad4681a01ca187f00c82106ba9c0)
#         ;
#
#
#
#
#             var marker_e4ac8ff9beaeaa1d3663fd018cb3e094 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(map_1e8fa9c41c79e78e2c7bb3072bcfe950);
#
#
#         var popup_19f2f8fc87eb0d987ec6bff19edf643c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21db5fedb84223509ce7165240490c34 = $(`&lt;div id=&quot;html_21db5fedb84223509ce7165240490c34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_19f2f8fc87eb0d987ec6bff19edf643c.setContent(html_21db5fedb84223509ce7165240490c34);
#
#
#
#         marker_e4ac8ff9beaeaa1d3663fd018cb3e094.bindPopup(popup_19f2f8fc87eb0d987ec6bff19edf643c)
#         ;
#
#
#
#
#             var marker_407fcf4cda98ad638e0acaf2f4d336db = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(map_1e8fa9c41c79e78e2c7bb3072bcfe950);
#
#
#         var popup_62aa2348d866a3f463afbcd2100014e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce319ca1f09f2807dc76008f7cacac90 = $(`&lt;div id=&quot;html_ce319ca1f09f2807dc76008f7cacac90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Discovery 4.3&lt;/div&gt;`)[0];
#                 popup_62aa2348d866a3f463afbcd2100014e2.setContent(html_ce319ca1f09f2807dc76008f7cacac90);
#
#
#
#         marker_407fcf4cda98ad638e0acaf2f4d336db.bindPopup(popup_62aa2348d866a3f463afbcd2100014e2)
#         ;
#
#
#
#
#             var marker_20f7e738bf2b94c25069aeaeda36f4ac = L.marker(
#                 [55.893181, 37.50108],
#                 {}

# %% [markdown]
# Здесь могут возникнуть проблемы:
#
# - Карта может долго отрисовываться, или рендериться (от англ. render, «выводить, отображать»), на слабых по производительности компьютерах или серверах;
# - Если на карте много точек, при уменьшении масштаба в ней будет сложно ориентироваться.
# - Из-за высокой нагрузки карта может зависать при передвижении по ней.
#
# Если отобразить на карте несколько тысяч точек, эти проблемы станут особенно заметны. Помогут кластеры — с их помощью можно поместить на карту много маркеров одновременно.
#
# Отметим все торговые центры на карте с помощью кластеров:

# %%
# импортируем карту и маркер
from folium import Map, Marker
# импортируем кластер
from folium.plugins import MarkerCluster

# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
df.apply(create_clusters, axis=1)

# выводим карту
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9567e86e113df5a6335afdc277b27b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9567e86e113df5a6335afdc277b27b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9567e86e113df5a6335afdc277b27b6 = L.map(
#                 &quot;map_c9567e86e113df5a6335afdc277b27b6&quot;,
#                 {
#                     center: [55.751244, 37.618423],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42206d0b3f71efa13e76760b1050a6c2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c9567e86e113df5a6335afdc277b27b6);
#
#
#             var marker_cluster_23d094559ebc1cef09bc9a18028f0ede = L.markerClusterGroup(
#                 {}
#             );
#             map_c9567e86e113df5a6335afdc277b27b6.addLayer(marker_cluster_23d094559ebc1cef09bc9a18028f0ede);
#
#
#             var marker_c9010f95502d57df135a5f8b7d9e8e3c = L.marker(
#                 [55.880803, 37.449824],
#                 {}
#             ).addTo(marker_cluster_23d094559ebc1cef09bc9a18028f0ede);
#
#
#         var popup_2f6ef2572701e49b09123748ceef2281 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13c1eb41b290760a2db9897cbd422a80 = $(`&lt;div id=&quot;html_13c1eb41b290760a2db9897cbd422a80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Капитолий 4.7&lt;/div&gt;`)[0];
#                 popup_2f6ef2572701e49b09123748ceef2281.setContent(html_13c1eb41b290760a2db9897cbd422a80);
#
#
#
#         marker_c9010f95502d57df135a5f8b7d9e8e3c.bindPopup(popup_2f6ef2572701e49b09123748ceef2281)
#         ;
#
#
#
#
#             var marker_b0bd8b756fac11ca990721f19abccc9f = L.marker(
#                 [55.893082, 37.501263],
#                 {}
#             ).addTo(marker_cluster_23d094559ebc1cef09bc9a18028f0ede);
#
#
#         var popup_d921c1c40315be19b3cd73d7c42898a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a72f49d02a438dea49e41aada41b576a = $(`&lt;div id=&quot;html_a72f49d02a438dea49e41aada41b576a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dexter 4.3&lt;/div&gt;`)[0];
#                 popup_d921c1c40315be19b3cd73d7c42898a8.setContent(html_a72f49d02a438dea49e41aada41b576a);
#
#
#
#         marker_b0bd8b756fac11ca990721f19abccc9f.bindPopup(popup_d921c1c40315be19b3cd73d7c42898a8)
#         ;
#
#
#
#
#             var marker_0fa9020000052958b64aba66a94db116 = L.marker(
#                 [55.909388, 37.539546],
#                 {}
#             ).addTo(marker_cluster_23d094559ebc1cef09bc9a18028f0ede);
#
#
#         var popup_470353114218411732f3276f7cfc1d92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b42d33434f44077bcbf3bc1c839f65f1 = $(`&lt;div id=&quot;html_b42d33434f44077bcbf3bc1c839f65f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;РИО 4.8&lt;/div&gt;`)[0];
#                 popup_470353114218411732f3276f7cfc1d92.setContent(html_b42d33434f44077bcbf3bc1c839f65f1);
#
#
#
#         marker_0fa9020000052958b64aba66a94db116.bindPopup(popup_470353114218411732f3276f7cfc1d92)
#         ;
#
#
#
#
#             var marker_88767f738e7cc92066705b11a4bc7d11 = L.marker(
#                 [55.869937, 37.469915],
#                 {}
#             ).addTo(marker_cluster_23d094559ebc1cef09bc9a18028f0ede);
#
#
#         var popup_7a3c03b93d5b6acad23e9432cf9788d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89601371f4f40ff2561e7a04a6a1a9ea = $(`&lt;div id=&quot;html_89601371f4f40ff2561e7a04a6a1a9ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Экстрим 4.7&lt;/div&gt;`)[0];
#                 popup_7a3c03b93d5b6acad23e9432cf9788d6.setContent(html_89601371f4f40ff2561e7a04a6a1a9ea);
#
#
#
#         marker_88767f738e7cc92066705b11a4bc7d11.bindPopup(popup_7a3c03b93d5b6acad23e9432cf9788d6)
#         ;
#
#
#
#
#             var marker_797d86ac5784e0dc90e492cf88a06aa9 = L.marker(
#                 [55.878662, 37.479251],
#                 {}
#             ).addTo(marker_cluster_23d094559ebc1cef09bc9a18028f0ede)

# %% [markdown]
# Попробуйте увеличить масштаб с помощью колёсика мышки или кнопок на карте. Вы увидите, что кластеры автоматически перегруппировываются: при достаточном приближении из кластеров начнут «выпадать» отдельные маркеры с торговыми центрами. Всплывающие окна и подсказки для них реализованы точно так же, как и для отдельных маркеров.
